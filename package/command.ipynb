# %%
# %matplotlib inline
# %run 3-load_data.py
# Out:
# ####################################################
# ####################################################
# @@@@@@@@@@@@ load_data start! @@@@@@@@@@@@
# @@@@@@@@@@@@ load_data end! @@@@@@@@@@@@
# ####################################################
# ####################################################
